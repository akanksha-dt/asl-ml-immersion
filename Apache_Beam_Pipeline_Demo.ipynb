# %% [markdown]
# <a href="https://colab.research.google.com/github/akanksha-dt/asl-ml-immersion/blob/master/Apache_Beam_Pipeline_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install apache_beam[interactive] --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 25.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 39.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 34.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 48.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.8/307.8 kB 23.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.2/809.2 kB 39.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.1/116.1 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 44.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 46.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.4/305.4 kB 25.4 MB/s eta 0:00:00
#   Building wheel for crcmod (setup.py) ... done
#   Building wheel for dill (setup.py) ... done
#   Building wheel for hdfs (setup.py) ... done
#   Building wheel for timeloop (setup.py) ... done
#   Building wheel for pyjsparser (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==5.5.6, but you have ipykernel 6.29.0 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.20.0 which is incompatible.
# notebook 6.5.5 requires pyzmq<25,>=17, but you have pyzmq 25.1.2 which is incompatible.

# %%
import apache_beam as beam
from apache_beam.runners.interactive.interactive_runner import InteractiveRunner
import apache_beam.runners.interactive.interactive_beam as ib

from datetime import datetime

# %%
p = beam.Pipeline(InteractiveRunner())

# %%
res = p | beam.Create([1,2,3,4,5]) | beam.Map (lambda x: x*100) | beam.io.WriteToText("Result","txt")

# %%
p.run()
# Out:
# WARNING:apache_beam.io.filebasedsink:Deleting 1 existing files in target path matching: -*-of-%(num_shards)05d

# %%
lines = {
    "Beam is great",
    "Beam is good to work"
}

# %%
words = p | beam.Create(lines) | beam.FlatMap(lambda x: x.split(" "))
ib.show(words)
ib.show_graph (p)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_42cee79e34cfdd9904c6b35b42e7b6b3">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_7c873c79aa1357c3261ec40a3400a36d" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_7c873c79aa1357c3261ec40a3400a36d")) {
#               dt = $("#table_df_7c873c79aa1357c3261ec40a3400a36d").dataTable();
#             } else if ($("#table_df_7c873c79aa1357c3261ec40a3400a36d_wrapper").length == 0) {
#               dt = $("#table_df_7c873c79aa1357c3261ec40a3400a36d").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'words.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Beam', 0: 0}, {1: 'is', 0: 1}, {1: 'good', 0: 2}, {1: 'to', 0: 3}, {1: 'work', 0: 4}, {1: 'Beam', 0: 5}, {1: 'is', 0: 6}, {1: 'great', 0: 7}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_7c873c79aa1357c3261ec40a3400a36d")) {
#               dt = $("#table_df_7c873c79aa1357c3261ec40a3400a36d").dataTable();
#             } else if ($("#table_df_7c873c79aa1357c3261ec40a3400a36d_wrapper").length == 0) {
#               dt = $("#table_df_7c873c79aa1357c3261ec40a3400a36d").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'words.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'Beam', 0: 0}, {1: 'is', 0: 1}, {1: 'good', 0: 2}, {1: 'to', 0: 3}, {1: 'work', 0: 4}, {1: 'Beam', 0: 5}, {1: 'is', 0: 6}, {1: 'great', 0: 7}])
#               .draw('full-hold');
#           });
#         }
#             </script>
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_864880f87e6f03776034f73b939086de">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show_graph</span>
#             </div>
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="2110pt" height="727pt"
#  viewBox="0.00 0.00 2109.50 726.59" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 722.59)">
# <title>G</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-722.59 2105.5,-722.59 2105.5,4 -4,4"/>
# <!-- [8]: Create -->
# <g id="node1" class="node">
# <title>[8]: Create</title>
# <polygon fill="none" stroke="blue" points="210,-718.59 135,-718.59 135,-682.59 210,-682.59 210,-718.59"/>
# <text text-anchor="middle" x="172.5" y="-696.89" font-family="Times,serif" font-size="14.00" fill="blue">[8]: Create</text>
# </g>
# <!-- pcoll2888 -->
# <g id="node2" class="node">
# <title>pcoll2888</title>
# <ellipse fill="none" stroke="blue" cx="172.5" cy="-628.59" rx="18" ry="18"/>
# </g>
# <!-- [8]: Create&#45;&gt;pcoll2888 -->
# <g id="edge1" class="edge">
# <title>[8]: Create&#45;&gt;pcoll2888</title>
# <path fill="none" stroke="black" d="M172.5,-682.29C172.5,-674.57 172.5,-665.3 172.5,-656.7"/>
# <polygon fill="black" stroke="black" points="176,-656.69 172.5,-646.69 169,-656.69 176,-656.69"/>
# </g>
# <!-- [8]: Map(&lt;lambda at &lt;ipython&#45;input&#45;8&#45;46e96d145784&gt;:1&gt;) -->
# <g id="node3" class="node">
# <title>[8]: Map(&lt;lambda at &lt;ipython&#45;input&#45;8&#45;46e96d145784&gt;:1&gt;)</title>
# <polygon fill="none" stroke="blue" points="345,-574.59 0,-574.59 0,-538.59 345,-538.59 345,-574.59"/>
# <text text-anchor="middle" x="172.5" y="-552.89" font-family="Times,serif" font-size="14.00" fill="blue">[8]: Map(&lt;lambda at &lt;ipython&#45;input&#45;8&#45;46e96d145784&gt;:1&gt;)</text>
# </g>
# <!-- pcoll2888&#45;&gt;[8]: Map(&lt;lambda at &lt;ipython&#45;input&#45;8&#45;46e96d145784&gt;:1&gt;) -->
# <g id="edge2" class="edge">
# <title>pcoll2888&#45;&gt;[8]: Map(&lt;lambda at &lt;ipython&#45;input&#45;8&#45;46e96d145784&gt;:1&gt;)</title>
# <path fill="none" stroke="black" d="M172.5,-610.29C172.5,-602.57 172.5,-593.3 172.5,-584.7"/>
# <polygon fill="black" stroke="black" points="176,-584.69 172.5,-574.69 169,-584.69 176,-584.69"/>
# </g>
# <!-- pcoll9760 -->
# <g id="node4" class="node">
# <title>pcoll9760</title>
# <ellipse fill="none" stroke="blue" cx="172.5" cy="-470.09" rx="18" ry="18"/>
# </g>
# <!-- [8]: Map(&lt;lambda at &lt;ipython&#45;input&#45;8&#45;46e96d145784&gt;:1&gt;)&#45;&gt;pcoll9760 -->
# <g id="edge3" class="edge">
# <title>[8]: Map(&lt;lambda at &lt;ipython&#45;input&#45;8&#45;46e96d145784&gt;:1&gt;)&#45;&gt;pcoll9760</title>
# <path fill="none" stroke="black" d="M172.5,-538.49C172.5,-526.92 172.5,-511.4 172.5,-498.17"/>
# <polygon fill="black" stroke="black" points="176,-498.17 172.5,-488.17 169,-498.17 176,-498.17"/>
# </g>
# <!-- [8]: WriteToText -->
# <g id="node5" class="node">
# <title>[8]: WriteToText</title>
# <polygon fill="none" stroke="blue" points="226.5,-401.6 118.5,-401.6 118.5,-365.6 226.5,-365.6 226.5,-401.6"/>
# <text text-anchor="middle" x="172.5" y="-379.9" font-family="Times,serif" font-size="14.00" fill="blue">[8]: WriteToText</text>
# </g>
# <!-- pcoll9760&#45;&gt;[8]: WriteToText -->
# <g id="edge4" class="edge">
# <title>pcoll9760&#45;&gt;[8]: WriteToText</title>
# <path fill="none" stroke="black" d="M172.5,-451.99C172.5,-440.43 172.5,-424.9 172.5,-411.67"/>
# <polygon fill="black" stroke="black" points="176,-411.67 172.5,-401.67 169,-411.67 176,-411.67"/>
# </g>
# <!-- pcoll3819 -->
# <g id="node6" class="node">
# <title>pcoll3819</title>
# <ellipse fill="none" stroke="blue" cx="172.5" cy="-308.8" rx="18" ry="18"/>
# </g>
# <!-- [8]: WriteToText&#45;&gt;pcoll3819 -->
# <g id="edge5" class="edge">
# <title>[8]: WriteToText&#45;&gt;pcoll3819</title>
# <path fill="none" stroke="black" d="M172.5,-365.34C172.5,-356.91 172.5,-346.57 172.5,-337.1"/>
# <polygon fill="black" stroke="black" points="176,-336.93 172.5,-326.93 169,-336.93 176,-336.93"/>
# </g>
# <!-- [10]: Create -->
# <g id="node7" class="node">
# <title>[10]: Create</title>
# <polygon fill="none" stroke="blue" points="581.5,-718.59 499.5,-718.59 499.5,-682.59 581.5,-682.59 581.5,-718.59"/>
# <text text-anchor="middle" x="540.5" y="-696.89" font-family="Times,serif" font-size="14.00" fill="blue">[10]: Create</text>
# </g>
# <!-- pcoll7116 -->
# <g id="node8" class="node">
# <title>pcoll7116</title>
# <ellipse fill="none" stroke="blue" cx="540.5" cy="-628.59" rx="18" ry="18"/>
# </g>
# <!-- [10]: Create&#45;&gt;pcoll7116 -->
# <g id="edge6" class="edge">
# <title>[10]: Create&#45;&gt;pcoll7116</title>
# <path fill="none" stroke="black" d="M540.5,-682.29C540.5,-674.57 540.5,-665.3 540.5,-656.7"/>
# <polygon fill="black" stroke="black" points="544,-656.69 540.5,-646.69 537,-656.69 544,-656.69"/>
# </g>
# <!-- [10]: Map(&lt;lambda at &lt;ipython&#45;input&#45;10&#45;2e1e78f848a0&gt;:1&gt;) -->
# <g id="node9" class="node">
# <title>[10]: Map(&lt;lambda at &lt;ipython&#45;input&#45;10&#45;2e1e78f848a0&gt;:1&gt;)</title>
# <polygon fill="none" stroke="blue" points="718,-574.59 363,-574.59 363,-538.59 718,-538.59 718,-574.59"/>
# <text text-anchor="middle" x="540.5" y="-552.89" font-family="Times,serif" font-size="14.00" fill="blue">[10]: Map(&lt;lambda at &lt;ipython&#45;input&#45;10&#45;2e1e78f848a0&gt;:1&gt;)</text>
# </g>
# <!-- pcoll7116&#45;&gt;[10]: Map(&lt;lambda at &lt;ipython&#45;input&#45;10&#45;2e1e78f848a0&gt;:1&gt;) -->
# <g id="edge7" class="edge">
# <title>pcoll7116&#45;&gt;[10]: Map(&lt;lambda at &lt;ipython&#45;input&#45;10&#45;2e1e78f848a0&gt;:1&gt;)</title>
# <path fill="none" stroke="black" d="M540.5,-610.29C540.5,-602.57 540.5,-593.3 540.5,-584.7"/>
# <polygon fill="black" stroke="black" points="544,-584.69 540.5,-574.69 537,-584.69 544,-584.69"/>
# </g>
# <!-- pcoll1044 -->
# <g id="node10" class="node">
# <title>pcoll1044</title>
# <ellipse fill="none" stroke="blue" cx="540.5" cy="-470.09" rx="18" ry="18"/>
# </g>
# <!-- [10]: Map(&lt;lambda at &lt;ipython&#45;input&#45;10&#45;2e1e78f848a0&gt;:1&gt;)&#45;&gt;pcoll1044 -->
# <g id="edge8" class="edge">
# <title>[10]: Map(&lt;lambda at &lt;ipython&#45;input&#45;10&#45;2e1e78f848a0&gt;:1&gt;)&#45;&gt;pcoll1044</title>
# <path fill="none" stroke="black" d="M540.5,-538.49C540.5,-526.92 540.5,-511.4 540.5,-498.17"/>
# <polygon fill="black" stroke="black" points="544,-498.17 540.5,-488.17 537,-498.17 544,-498.17"/>
# </g>
# <!-- [10]: WriteToText -->
# <g id="node11" class="node">
# <title>[10]: WriteToText</title>
# <polygon fill="none" stroke="blue" points="598,-401.6 483,-401.6 483,-365.6 598,-365.6 598,-401.6"/>
# <text text-anchor="middle" x="540.5" y="-379.9" font-family="Times,serif" font-size="14.00" fill="blue">[10]: WriteToText</text>
# </g>
# <!-- pcoll1044&#45;&gt;[10]: WriteToText -->
# <g id="edge9" class="edge">
# <title>pcoll1044&#45;&gt;[10]: WriteToText</title>
# <path fill="none" stroke="black" d="M540.5,-451.99C540.5,-440.43 540.5,-424.9 540.5,-411.67"/>
# <polygon fill="black" stroke="black" points="544,-411.67 540.5,-401.67 537,-411.67 544,-411.67"/>
# </g>
# <!-- pcoll1684 -->
# <g id="node12" class="node">
# <title>pcoll1684</title>
# <ellipse fill="none" stroke="blue" cx="540.5" cy="-308.8" rx="18" ry="18"/>
# </g>
# <!-- [10]: WriteToText&#45;&gt;pcoll1684 -->
# <g id="edge10" class="edge">
# <title>[10]: WriteToText&#45;&gt;pcoll1684</title>
# <path fill="none" stroke="black" d="M540.5,-365.34C540.5,-356.91 540.5,-346.57 540.5,-337.1"/>
# <polygon fill="black" stroke="black" points="544,-336.93 540.5,-326.93 537,-336.93 544,-336.93"/>
# </g>
# <!-- [11]: ReifyBefore_WriteCache_9b207167e5&#45;134682579990944&#45;134682579992000&#45;134682585246128 -->
# <g id="node13" class="node">
# <title>[11]: ReifyBefore_WriteCache_9b207167e5&#45;134682579990944&#45;134682579992000&#45;134682585246128</title>
# <polygon fill="none" stroke="blue" points="828,-252 253,-252 253,-216 828,-216 828,-252"/>
# <text text-anchor="middle" x="540.5" y="-230.3" font-family="Times,serif" font-size="14.00" fill="blue">[11]: ReifyBefore_WriteCache_9b207167e5&#45;

# %%
# First we need to implement the function that does the math. We create a new class that extends the beam.DoFn and overwrite the process() method
class MultiplyByTenDoFn(beam.DoFn):
  # This method
  def process(self, element):
    print("Processing element: %s" % element)
    # Note: an iterable object must be return
    yield element*10
  # Can be use to customize the behavoir when the bundle of element starts. This is called before process function
  def start_bundle(self):
    print("Bundle started at ", datetime.now().strftime("%d/%m/%Y %H:%M:%S"))
  # Can be use to customize the behavoir when the processing has done on the bundle. This is called after process function and it can be used for running a batch query
  def finish_bundle(self):
    print("Bundle finished at ", datetime.now().strftime("%d/%m/%Y %H:%M:%S"))
  # Can be used to customize the worker behavior at start up. Common operations might be connecting to a db
  def setup(self):
    print("Worker started at ", datetime.now().strftime("%d/%m/%Y %H:%M:%S"))
  # Can be used to customize the worker behavior at shut down. Common operations might be disconnecting to a db
  def teardown(self):
    print("Worker finished at ", datetime.now().strftime("%d/%m/%Y %H:%M:%S"))

# %%
p = beam.Pipeline(InteractiveRunner())
res = p | beam.Create([1,2,3,4,5]) | beam.ParDo(MultiplyByTenDoFn()) | beam.io.WriteToText("ResultParDo.txt")

# %%
p.run ()
# Out:
# Worker started at  30/01/2024 15:47:53
# Bundle started at  30/01/2024 15:47:53
# Processing element: 1
# Processing element: 2
# Processing element: 3
# Processing element: 4
# Processing element: 5
# Bundle finished at  30/01/2024 15:47:53
# Worker finished at  30/01/2024 15:47:53

# %%
p = beam.Pipeline(InteractiveRunner())
inventory = [
    ("winter", 8),
    ("summer", 10),
    ("spring", 4),
    ("summer", 6),
    ("winter", 3),
    ("winter", 1),
    ("winter", 5),
    ("winter", 9),
    ("autumn", 8)
]
gbk = p | beam.Create(inventory) | beam.GroupByKey()
ib.show(gbk)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_b49ce688b8f5f31718e038429a86dc5f">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_a27a01ad5a3100bde677db4f58a2a92f" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_a27a01ad5a3100bde677db4f58a2a92f")) {
#               dt = $("#table_df_a27a01ad5a3100bde677db4f58a2a92f").dataTable();
#             } else if ($("#table_df_a27a01ad5a3100bde677db4f58a2a92f_wrapper").length == 0) {
#               dt = $("#table_df_a27a01ad5a3100bde677db4f58a2a92f").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'gbk.0'}, {'title': 'gbk.1'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'winter', 2: '[8, 3, 1, 5, 9]', 0: 0}, {1: 'summer', 2: '[10, 6]', 0: 1}, {1: 'spring', 2: '[4]', 0: 2}, {1: 'autumn', 2: '[8]', 0: 3}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_a27a01ad5a3100bde677db4f58a2a92f")) {
#               dt = $("#table_df_a27a01ad5a3100bde677db4f58a2a92f").dataTable();
#             } else if ($("#table_df_a27a01ad5a3100bde677db4f58a2a92f_wrapper").length == 0) {
#               dt = $("#table_df_a27a01ad5a3100bde677db4f58a2a92f").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'gbk.0'}, {'title': 'gbk.1'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'winter', 2: '[8, 3, 1, 5, 9]', 0: 0}, {1: 'summer', 2: '[10, 6]', 0: 1}, {1: 'spring', 2: '[4]', 0: 2}, {1: 'autumn', 2: '[8]', 0: 3}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
users = [
    ("001", "Mark"),
    ("002", "John"),
    ("003", "Eva")
]

orders = [
    ("001", "iPhone13"),
    ("002", "iPhone14"),
    ("003", "iPad Pro"),
    ("003", "Macbook M1 Pro"),
    ("001", "Apple watch")
]

p = beam.Pipeline(InteractiveRunner())

# %%
users_PCollection = p | "Create users PCollection " >> beam.Create(users)
orders_PCollection = p | "Create orders PCollection " >> beam.Create(orders)

joined_table_by_user_id = ({"users": users_PCollection, "orders": orders_PCollection}) | "Merge Tables" >> beam.CoGroupByKey() | "Print Joined Table " >> beam.Map(print)

# %%
p.run()
ib.show(joined_table_by_user_id)
ib.show_graph(p)
# Out:
# WARNING:apache_beam.io.filebasedsink:Deleting 1 existing files in target path matching: -*-of-%(num_shards)05d
# WARNING:apache_beam.io.filebasedsink:Deleting 1 existing files in target path matching: -*-of-%(num_shards)05d
# WARNING:apache_beam.io.filebasedsink:Deleting 1 existing files in target path matching: -*-of-%(num_shards)05d
# ('001', {'users': ['Mark'], 'orders': ['iPhone13', 'Apple watch']})
# ('002', {'users': ['John'], 'orders': ['iPhone14']})
# ('003', {'users': ['Eva'], 'orders': ['iPad Pro', 'Macbook M1 Pro']})
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_50af173abe3f026ade76379e514940f0">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
# ('001', {'users': ['Mark'], 'orders': ['iPhone13', 'Apple watch']})
# ('002', {'users': ['John'], 'orders': ['iPhone14']})
# ('003', {'users': ['Eva'], 'orders': ['iPad Pro', 'Macbook M1 Pro']})
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_09b31f0ebf0f1668aa1f1b62bb9fbe69" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_09b31f0ebf0f1668aa1f1b62bb9fbe69")) {
#               dt = $("#table_df_09b31f0ebf0f1668aa1f1b62bb9fbe69").dataTable();
#             } else if ($("#table_df_09b31f0ebf0f1668aa1f1b62bb9fbe69_wrapper").length == 0) {
#               dt = $("#table_df_09b31f0ebf0f1668aa1f1b62bb9fbe69").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'joined_table_by_user_id.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'None', 0: 0}, {1: 'None', 0: 1}, {1: 'None', 0: 2}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_09b31f0ebf0f1668aa1f1b62bb9fbe69")) {
#               dt = $("#table_df_09b31f0ebf0f1668aa1f1b62bb9fbe69").dataTable();
#             } else if ($("#table_df_09b31f0ebf0f1668aa1f1b62bb9fbe69_wrapper").length == 0) {
#               dt = $("#table_df_09b31f0ebf0f1668aa1f1b62bb9fbe69").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'joined_table_by_user_id.0'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: 'None', 0: 0}, {1: 'None', 0: 1}, {1: 'None', 0: 2}])
#               .draw('full-hold');
#           });
#         }
#             </script>
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_fcd09d29e765fb0d633357e47f128dec">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show_graph</span>
#             </div>
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="1315pt" height="972pt"
#  viewBox="0.00 0.00 1315.00 972.27" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 968.27)">
# <title>G</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-968.27 1311,-968.27 1311,4 -4,4"/>
# <!-- [26]: Create users PCollection  -->
# <g id="node1" class="node">
# <title>[26]: Create users PCollection </title>
# <polygon fill="none" stroke="blue" points="257,-964.27 72,-964.27 72,-928.27 257,-928.27 257,-964.27"/>
# <text text-anchor="middle" x="164.5" y="-942.57" font-family="Times,serif" font-size="14.00" fill="blue">[26]: Create users PCollection </text>
# </g>
# <!-- pcoll2888 -->
# <g id="node2" class="node">
# <title>pcoll2888</title>
# <ellipse fill="none" stroke="blue" cx="164.5" cy="-813.63" rx="18" ry="18"/>
# </g>
# <!-- [26]: Create users PCollection &#45;&gt;pcoll2888 -->
# <g id="edge1" class="edge">
# <title>[26]: Create users PCollection &#45;&gt;pcoll2888</title>
# <path fill="none" stroke="black" d="M164.5,-928.19C164.5,-906.28 164.5,-868.02 164.5,-842.02"/>
# <polygon fill="black" stroke="black" points="168,-841.71 164.5,-831.71 161,-841.71 168,-841.71"/>
# </g>
# <!-- [27]: Create users PCollection  -->
# <g id="node3" class="node">
# <title>[27]: Create users PCollection </title>
# <polygon fill="none" stroke="blue" points="460,-964.27 275,-964.27 275,-928.27 460,-928.27 460,-964.27"/>
# <text text-anchor="middle" x="367.5" y="-942.57" font-family="Times,serif" font-size="14.00" fill="blue">[27]: Create users PCollection </text>
# </g>
# <!-- users_PCollection -->
# <g id="node4" class="node">
# <title>users_PCollection</title>
# <ellipse fill="none" stroke="blue" cx="367.5" cy="-813.63" rx="74.99" ry="74.99"/>
# <text text-anchor="middle" x="367.5" y="-809.93" font-family="Times,serif" font-size="14.00" fill="blue">users_PCollection</text>
# </g>
# <!-- [27]: Create users PCollection &#45;&gt;users_PCollection -->
# <g id="edge2" class="edge">
# <title>[27]: Create users PCollection &#45;&gt;users_PCollection</title>
# <path fill="none" stroke="black" d="M367.5,-928.19C367.5,-920.14 367.5,-909.88 367.5,-898.84"/>
# <polygon fill="black" stroke="black" points="371,-898.51 367.5,-888.51 364,-898.51 371,-898.51"/>
# </g>
# <!-- [27]: Merge Tables -->
# <g id="node7" class="node">
# <title>[27]: Merge Tables</title>
# <polygon fill="none" stroke="blue" points="714,-698.98 593,-698.98 593,-662.98 714,-662.98 714,-698.98"/>
# <text text-anchor="middle" x="653.5" y="-677.28" font-family="Times,serif" font-size="14.00" fill="blue">[27]: Merge Tables</text>
# </g>
# <!-- users_PCollection&#45;&gt;[27]: Merge Tables -->
# <g id="edge3" class="edge">
# <title>users_PCollection&#45;&gt;[27]: Merge Tables</title>
# <path fill="none" stroke="black" d="M435.28,-781.67C488.13,-757.52 560.15,-724.63 606.73,-703.35"/>
# <polygon fill="black" stroke="black" points="608.34,-706.46 615.99,-699.12 605.44,-700.09 608.34,-706.46"/>
# </g>
# <!-- [28]: ReifyBefore_WriteCache_28121b1c45&#45;134682318099728&#45;134682318097856&#45;134682543173792 -->
# <g id="node11" class="node">
# <title>[28]: ReifyBefore_WriteCache_28121b1c45&#45;134682318099728&#45;134682318097856&#45;134682543173792</title>
# <polygon fill="none" stroke="blue" points="575,-698.98 0,-698.98 0,-662.98 575,-662.98 575,-698.98"/>
# <text text-anchor="middle" x="287.5" y="-677.28" font-family="Times,serif" font-size="14.00" fill="blue">[28]: ReifyBefore_WriteCache_28121b1c45&#45;134682318099728&#45;134682318097856&#45;134682543173792</text>
# </g>
# <!-- users_PCollection&#45;&gt;[28]: ReifyBefore_WriteCache_28121b1c45&#45;134682318099728&#45;134682318097856&#45;134682543173792 -->
# <g id="edge4" class="edge">
# <title>users_PCollection&#45;&gt;[28]: ReifyBefore_WriteCache_28121b1c45&#45;134682318099728&#45;134682318097856&#45;134682543173792</title>
# <path fill="none" stroke="black" d="M328.91,-749.6C319.86,-734.83 310.72,-719.91 303.34,-707.85"/>
# <polygon fill="black" stroke="black" points="306.28,-705.94 298.07,-699.24 300.31,-709.6 306.28,-705.94"/>
# </g>
# <!-- [27]: Create orders PCollection  -->
# <g id="node5" class="node">
# <title>[27]: Create orders PCollection </title>
# <polygon fill="none" stroke="blue" points="932,-964.27 741,-964.27 741,-928.27 932,-928.27 932,-964.27"/>
# <text text-anchor="middle" x="836.5" y="-942.57" font-family="Times,serif" font-size="14.00" fill="blue">[27]: Create orders PCollection </text>
# </g>
# <!-- orders_PCollection -->
# <g id="node6" class="node">
# <title>orders_PCollection</title>
# <ellipse fill="none" stroke="blue" cx="836.5" cy="-813.63" rx="78.79" ry="78.79"/>
# <text text-anchor="middle" x="836.5" y="-809.93" font-family="Times,serif" font-size="14.00" fill="blue">orders_PCollection</text>
# </g>
# <!-- [27]: Create orders PCollection &#45;&gt;orders_PCollection -->
# <g id="edge5" class="edge">
# <title>[27]: Create orders PCollection &#45;&gt;orders_PCollection</title>
# <path fill="none" stroke="black" d="M836.5,-928.19C836.5,-921.05 836.5,-912.18 836.5,-902.57"/>
# <polygon fill="black" stroke="black" points="840,-902.32 836.5,-892.32 833,-902.32 840,-902.32"/>
# </g>
# <!-- orders_PCollection&#45;&gt;[27]: Merge Tables -->
# <g id="edge6" class="edge">
# <title>orders_PCollection&#45;&gt;[27]: Merge Tables</title>
# <path fill="none" stroke="black" d="M772.75,-767.12C743.54,-746.26 710.15,-722.43 686.15,-705.29"/>
# <polygon fill="black" stroke="black" points="687.93,-702.26 677.76,-699.3 683.87,-707.96 687.93,-702.26"/>
# </g>
# <!-- [28]: ReifyBefore_WriteCache_1b7e462351&#45;134682318119856&#45;134682318123888&#45;134682543173792 -->
# <g id="node15" class="node">
# <title>[28]: ReifyBefore_WriteCache_1b7e462351&#45;134682318119856&#45;134682318123888&#45;134682543173792</title>
# <polygon fill="none" stroke="blue" points="1307,-698.98 732,-698.98 732,-662.98 1307,-662.98 1307,-698.98"/>
# <text text-anchor="middle" x="1019.5" y="-677.28" font-family="Times,serif" font-size="14.00" fill="blue">[28]: ReifyBefore_WriteCache_1b7e462351&#45;134682318119856&#45;134682318123888&#45;134682543173792</text>
# </g>
# <!-- orders_PCollection&#45;&gt;[28]: ReifyBefore_WriteCache_1b7e462351&#45;134682318119856&#45;134682318123888&#45;134682543173792 -->
# <g id="edge7" class="edge">
# <title>orders_PCollection&#45;&gt;[28]: ReifyBefore_WriteCache_1b7e462351&#45;134682318119856&#45;134682318123888&#45;134682543173792</title>
# <path fill="none" stroke="black" d="M900.25,-767.12C929.46,-746.26 962.85,-722.43 986.85,-705.29"/>
# <polygon fill="black" stroke="black" points="989.13,-707.96 995.24,-699.3 985.07,-702.26 989.13,-707.96"/>
# </g>
# <!-- pcoll1044 -->
# <g id="node8" class="node">
# <title>pcoll1044</title>
# <ellipse fill="none" stroke="blue" cx="653.5" cy="-608.98" rx="18" ry="18"/>
# </g>
# <!-- [27]: Merge Tables&#45;&gt;pcoll1044 -->
# <g id="edge8" class="edge">
# <title>[27]: Merge Tables&#45;&gt;pcoll1044</title>
# <path fill="none" stroke="black" d="M653.5,-662.68C653.5,-654.97 653.5,-645.7 653.5,-637.1"/>
# <polygon fill="black" stroke="black" points="657,-637.09 653.5,-627.09 650,-637.09 657,-637.09"/>
# </g>
# <!-- [27]: Print Joined Table  -->
# <g id="node9" class="node">
# <title>[27]: Print Joined Table </title>
# <polygon fill="none" stroke="blue" points="728,-554.98 579,-554.98 579,-518.98 728,-518.98 728,-554.98"/>
# <text text-anchor="middle" x="653.5" y="-533.28" font-family="Times,serif" font-size="14.00" fill="blue">[27]: Print Joined Table </text>
# </g>
# <!-- pcoll1044&#45;&gt;[27]: Print Joined Table  -->
# <g id="edge9" class="edge">
# <title>pcoll1044&#45;&gt;[27]: Print Joined Table </title>
# <path fill="none" stroke="black" d="M653.5,-590.68C653.5,-582.97 653.5,-573.7 653.5,-565.1"/>
# <polygon fill="black" stroke="black" points="657,-565.09 653.5,-555.09 650,-565.09 657,-565.09"/>
# </g>
# <!-- joined_table_by_user_id -->
# <g id="node10" class="
